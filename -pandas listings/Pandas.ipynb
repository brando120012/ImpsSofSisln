# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 538.3 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\docente1\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\docente1\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 2.0 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/11.5 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.5 MB 6.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.5 MB 9.2 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.5 MB 11.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.7/11.5 MB 14.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.5 MB 15.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.9/11.5 MB 17.2 MB/s eta 0:00:01
#    ------------------------- -------------- 7.2/11.5 MB 19.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.6/11.5 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.8/11.5 MB 20.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 23.3 MB/s eta 0:00:00
# Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.5/12.6 MB 30.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.7/12.6 MB 28.7 MB/s eta 0:00:01
#    ------------ --------------------------- 4.0/12.6 MB 28.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.6 MB 25.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.5/12.6 MB 27.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.5/12.6 MB 26.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 26.5 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 26.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  12.5/12.6 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 23.4 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#     --------------------------------------- 10.2/509.2 kB ? eta -:--:--
#    --------------------------------------- 509.2/509.2 kB 10.6 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ---------------------------------------- 0.0/347.8 kB ? eta -:--:--
#    --------------------------------------- 347.8/347.8 kB 22.5 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.5 pandas-2.2.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("listings.csv")
#       3 df.head()
#
# NameError: name 'pd' is not defined

# %%
df.tail(n = 10) # The last 10 rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.tail(n = 10)
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
#                  id       host_id  neighbourhood_group  neighbourhood  \
# count  1.543100e+04  1.543100e+04                  0.0   15431.000000
# mean   5.649547e+17  1.729455e+08                  NaN   78724.371395
# std    5.299163e+17  1.910468e+08                  NaN      20.723928
# min    5.456000e+03  2.300000e+01                  NaN   78701.000000
# 25%    3.139013e+07  1.825323e+07                  NaN   78704.000000
# 50%    6.687025e+17  8.177234e+07                  NaN   78723.000000
# 75%    1.077367e+18  2.963348e+08                  NaN   78745.000000
# max    1.369973e+18  6.821464e+08                  NaN   78759.000000
#
#            latitude     longitude         price  minimum_nights  \
# count  15431.000000  15431.000000  11029.000000    15431.000000
# mean      30.279937    -97.750596    341.934627        7.714341
# std        0.063867      0.064620    797.943897       29.975846
# min       30.078440    -98.053350     13.000000        1.000000
# 25%       30.241825    -97.768605    114.000000        1.000000
# 50%       30.269050    -97.741463    189.000000        2.000000
# 75%       30.308945    -97.717043    332.000000        3.000000
# max       30.518350    -97.559300  39741.000000     1124.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       15431.000000       12394.000000                    15431.000000
# mean           42.834230           1.423461                       10.124749
# std            89.225489           1.641482                       20.930417
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.230000                        1.000000
# 50%             9.000000           0.880000                        2.000000
# 75%            44.000000           2.070000                        6.000000
# max          1261.000000          21.350000                      111.000000
#
#        availability_365  number_of_reviews_ltm  license
# count      15431.000000           15431.000000      0.0
# mean         140.200376               9.907135      NaN
# std          141.478141              16.776291      NaN
# min            0.000000               0.000000      NaN
# 25%            0.000000               0.000000      NaN
# 50%           88.000000               2.000000      NaN
# 75%          288.000000              13.000000      NaN
# max          365.000000             224.000000      NaN

# %%
df.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.info(show_counts=True, memory_usage=True, verbose=True)
#
# NameError: name 'df' is not defined

# %%
df.shape # Get the number of rows and columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license']

# %%
df[['name']]
# Out:
#                                                     name
# 0              Walk to 6th, Rainey St and Convention Ctr
# 1                                         NW Austin Room
# 2                          Gem of a Studio near Downtown
# 3      Secluded Studio @ Zilker - King Bed, Bright & ...
# 4                                Woodland Studio Lodging
# ...                                                  ...
# 15426                                         Flex basic
# 15427  Stylish & Lux Stay | Walk to Top Eats & Pickle...
# 15428                   Hill Country Hideout-Pool-HotTub
# 15429  Vibrant East Austin Retreat Private 2 Bedroom ...
# 15430  Hot Tub & Pool, Stunning 4BD Near Domain & Cap...
#
# [15431 rows x 1 columns]

# %%
df[['name', 'neighbourhood_group']]
# Out:
#                                                     name  neighbourhood_group
# 0              Walk to 6th, Rainey St and Convention Ctr                  NaN
# 1                                         NW Austin Room                  NaN
# 2                          Gem of a Studio near Downtown                  NaN
# 3      Secluded Studio @ Zilker - King Bed, Bright & ...                  NaN
# 4                                Woodland Studio Lodging                  NaN
# ...                                                  ...                  ...
# 15426                                         Flex basic                  NaN
# 15427  Stylish & Lux Stay | Walk to Top Eats & Pickle...                  NaN
# 15428                   Hill Country Hideout-Pool-HotTub                  NaN
# 15429  Vibrant East Austin Retreat Private 2 Bedroom ...                  NaN
# 15430  Hot Tub & Pool, Stunning 4BD Near Domain & Cap...                  NaN
#
# [15431 rows x 2 columns]
